# %% [markdown]
# ![rmotr](https://user-images.githubusercontent.com/7065401/52071918-bda15380-2562-11e9-828c-7f95297e4a82.png)
# <hr style="margin-bottom: 40px;">
#
# <img src="https://user-images.githubusercontent.com/7065401/58563302-42466a80-8201-11e9-9948-b3e9f88a5662.jpg"
#     style="width:400px; float: right; margin: 0 40px 40px 40px;"></img>
#
# # Exercises
# ## Bike store sales

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## Hands on!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import seaborn as sns

# %matplotlib inline

# %%
sales = pd.read_csv(
    'data/sales_data.csv',
    parse_dates=['Date'])

# %%
sales.head()
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013            19     Youth (<25)
# 1 2015-11-26   26  November  2015            19     Youth (<25)
# 2 2014-03-23   23     March  2014            49  Adults (35-64)
# 3 2016-03-23   23     March  2016            49  Adults (35-64)
# 4 2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What's the mean of `Customers_Age`?

# %%
# your code goes here
sales['Customer_Age'].mean()
# Out:
# 35.91921157861212

# %% [markdown]
# Why don't you try with `.mean()`

# %%
sales['Customer_Age'].mean()
# Out:
# 35.91921157861212

# %% [markdown]
# Go ahead and show a <b>density (KDE)</b> and a <b>box plot</b> with the `Customer_Age` data:

# %%
# your code goes here
sales['Customer_Age'].plot(kind='kde'  , figsize=(10,5))
plt.xlabel('Sepal Length')
plt.ylabel('Probabidlity Density')
# Out:
# Text(0, 0.5, 'Probabidlity Density')

# %%
sales['Customer_Age'].plot(kind='kde', figsize=(14,6))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sales['Customer_Age'].plot(kind='box', vert=False, figsize=(14,6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What's the mean of `Order_Quantity`?

# %%
# your code goes here
sales['Order_Quantity'].mean()
# Out:
# 11.901659648253654

# %%
sales['Order_Quantity'].mean()
# Out:
# 11.901659648253654

# %% [markdown]
# Go ahead and show a <b>histogram</b> and a <b>box plot</b> with the `Order_Quantity` data:

# %%
# your code goes here
sales['Order_Quantity'].plot(kind='hist',bins=50 ,alpha=0.5,  figsize=(10,5))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sales['Order_Quantity'].plot(kind='hist', bins=30, figsize=(14,6))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sales['Order_Quantity'].plot(kind='box', vert=False, figsize=(14,6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales per year do we have?

# %%
# your code goes here
sales['Count']=1
sales.groupby('Year').count()['Count']
# Out:
# Year
# 2011     2677
# 2012     2677
# 2013    24443
# 2014    29398
# 2015    24443
# 2016    29398
# Name: Count, dtype: int64

# %%
sales['Year'].value_counts()
# Out:
# 2014    29398
# 2016    29398
# 2013    24443
# 2015    24443
# 2011     2677
# 2012     2677
# Name: Year, dtype: int64

# %% [markdown]
# Go ahead and show a <b>pie plot</b> with the previous data:

# %%
# your code goes here
sales['Count']=1
sales.groupby('Year').count()['Count'].plot(kind='pie' , figsize=(7,7))
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sales['Year'].value_counts().plot(kind='pie', figsize=(6,6))
# Out:
# <AxesSubplot:ylabel='Year'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales per month do we have?

# %%
# your code goes here
sales['Month'].value_counts()
# Out:
# June         11234
# December     11200
# May          11128
# April        10182
# March         9674
# January       9284
# February      9022
# October       8750
# November      8734
# August        8200
# September     8166
# July          7462
# Name: Month, dtype: int64

# %%
sales['Month'].value_counts()
# Out:
# June         11234
# December     11200
# May          11128
# April        10182
# March         9674
# January       9284
# February      9022
# October       8750
# November      8734
# August        8200
# September     8166
# July          7462
# Name: Month, dtype: int64

# %% [markdown]
# Go ahead and show a <b>bar plot</b> with the previous data:

# %%
# your code goes here
sales['Month'].value_counts().plot(kind='bar',  figsize=(14,6))
# Out:
# <AxesSubplot:>

# %%
sales['Month'].value_counts().plot(kind='bar', figsize=(14,6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Which country has the most sales `quantity of sales`?

# %%
# your code goes here
print(sales['Country'].value_counts().idxmax(),sales['Country'].value_counts().max())
# Out:
# United States 39206

# %%
sales['Country'].value_counts().head(1)
# sales['Country'].value_counts().tail(1)
# Out:
# United States    39206
# Name: Country, dtype: int64

# %%
sales['Country'].value_counts()
# Out:
# United States     39206
# Australia         23936
# Canada            14178
# United Kingdom    13620
# Germany           11098
# France            10998
# Name: Country, dtype: int64

# %% [markdown]
# Go ahead and show a <b>bar plot</b> of the sales per country:

# %%
# your code goes here
plt.figure(figsize=(16,8))
ax1 = plt.subplot(121, aspect='equal')
sales['Country'].value_counts().plot(kind='pie', ax=ax1, autopct='%1.1f%%', 
 startangle=40, shadow=False, legend = True, fontsize=14)
# Out:
# <AxesSubplot:ylabel='Country'>

# %%
sales['Country'].value_counts().plot(kind='bar', figsize=(14,6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Create a list of every product sold

# %%
# your code goes here

Row_list =[]
for index, rows in sales.iterrows():
    my_list =rows.Product
    Row_list.append(my_list)
final_Row_list = list(dict.fromkeys(Row_list))  
print(final_Row_list)
# Out:
# ['Hitch Rack - 4-Bike', 'All-Purpose Bike Stand', 'Mountain Bottle Cage', 'Water Bottle - 30 oz.', 'Road Bottle Cage', 'AWC Logo Cap', 'Bike Wash - Dissolver', 'Fender Set - Mountain', 'Half-Finger Gloves, L', 'Half-Finger Gloves, M', 'Half-Finger Gloves, S', 'Sport-100 Helmet, Black', 'Sport-100 Helmet, Red', 'Sport-100 Helmet, Blue', 'Hydration Pack - 70 oz.', 'Short-Sleeve Classic Jersey, XL', 'Short-Sleeve Classic Jersey, L', 'Short-Sleeve Classic Jersey, M', 'Short-Sleeve Classic Jersey, S', 'Long-Sleeve Logo Jersey, M', 'Long-Sleeve Logo Jersey, XL', 'Long-Sleeve Logo Jersey, L', 'Long-Sleeve Logo Jersey, S', 'Mountain-100 Silver, 38', 'Mountain-100 Silver, 44', 'Mountain-100 Black, 48', 'Mountain-100 Silver, 48', 'Mountain-100 Black, 38', 'Mountain-200 Silver, 38', 'Mountain-100 Black, 44', 'Mountain-100 Silver, 42', 'Mountain-200 Black, 46', 'Mountain-200 Silver, 42', 'Mountain-200 Silver, 46', 'Mountain-200 Black, 38', 'Mountain-100 Black, 42', 'Mountain-200 Black, 42', 'Mou
# ...

# %%
#sales.loc[:, 'Product'].unique()

sales['Product'].unique()
# Out:
# array(['Hitch Rack - 4-Bike', 'All-Purpose Bike Stand',
#        'Mountain Bottle Cage', 'Water Bottle - 30 oz.',
#        'Road Bottle Cage', 'AWC Logo Cap', 'Bike Wash - Dissolver',
#        'Fender Set - Mountain', 'Half-Finger Gloves, L',
#        'Half-Finger Gloves, M', 'Half-Finger Gloves, S',
#        'Sport-100 Helmet, Black', 'Sport-100 Helmet, Red',
#        'Sport-100 Helmet, Blue', 'Hydration Pack - 70 oz.',
#        'Short-Sleeve Classic Jersey, XL',
#        'Short-Sleeve Classic Jersey, L', 'Short-Sleeve Classic Jersey, M',
#        'Short-Sleeve Classic Jersey, S', 'Long-Sleeve Logo Jersey, M',
#        'Long-Sleeve Logo Jersey, XL', 'Long-Sleeve Logo Jersey, L',
#        'Long-Sleeve Logo Jersey, S', 'Mountain-100 Silver, 38',
#        'Mountain-100 Silver, 44', 'Mountain-100 Black, 48',
#        'Mountain-100 Silver, 48', 'Mountain-100 Black, 38',
#        'Mountain-200 Silver, 38', 'Mountain-100 Black, 44',
# ...

# %% [markdown]
# Create a **bar plot** showing the 10 most sold products (best sellers):

# %%
# your code goes here

# sales['Product'].value_counts()[:10].index.tolist()
sales['Product'].value_counts().head(10).plot(kind='bar', figsize=(14,6))
# Out:
# <AxesSubplot:>

# %%
sales['Product'].value_counts().head(10).plot(kind='bar', figsize=(14,6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between `Unit_Cost` and `Unit_Price`?
#
# Show a <b>scatter plot</b> between both columns.

# %%
# your code goes here

# plt.scatter(sales["Unit_Cost"], sales["Unit_Price"])
sales.plot(kind='scatter', x='Unit_Cost', y='Unit_Price')
# Out:
# <AxesSubplot:xlabel='Unit_Cost', ylabel='Unit_Price'>

# %%
sales.plot(kind='scatter', x='Unit_Cost', y='Unit_Price', figsize=(6,6))
# Out:
# <AxesSubplot:xlabel='Unit_Cost', ylabel='Unit_Price'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between `Order_Quantity` and `Profit`?
#
# Show a <b>scatter plot</b> between both columns.

# %%
# your code goes here
sales.plot(kind='scatter', x='Order_Quantity', y='Profit', figsize=(6,6))
# Out:
# <AxesSubplot:xlabel='Order_Quantity', ylabel='Profit'>

# %%
sales.plot(kind='scatter', x='Order_Quantity', y='Profit', figsize=(6,6))
# Out:
# <AxesSubplot:xlabel='Order_Quantity', ylabel='Profit'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between `Profit` per `Country`?
#
# Show a grouped <b>box plot</b> per country with the profit values.

# %%
# your code goes here
sales[['Country','Profit']].boxplot( by='Country', figsize=(10,9))
# Out:
# <AxesSubplot:title={'center':'Profit'}, xlabel='[Country]'>

# %%
sales[['Profit', 'Country']].boxplot(by='Country', figsize=(10,6))
# Out:
# <AxesSubplot:title={'center':'Profit'}, xlabel='[Country]'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between the `Customer_Age` per `Country`?
#
# Show a grouped <b>box plot</b> per country with the customer age values.

# %%
# your code goes here
sales[['Customer_Age','Country']].boxplot(by='Country',figsize=(10,6))
# Out:
# <AxesSubplot:title={'center':'Customer_Age'}, xlabel='[Country]'>

# %%
sales[['Customer_Age', 'Country']].boxplot(by='Country', figsize=(10,6))
# Out:
# <AxesSubplot:title={'center':'Customer_Age'}, xlabel='[Country]'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add and calculate a new `Calculated_Date` column
#
# Use `Day`, `Month`, `Year` to create a `Date` column (`YYYY-MM-DD`).

# %%
# your code goes here
converted_list=[]
final_list = []
for index, rows in sales.iterrows():
    my_list =[rows.Year,rows.Month,rows.Day]
    converted_list = [str(element) for element in my_list]
    final_list.append("-".join(converted_list))

sales['Calculated_Date'] = final_list
sales['Calculated_Date'].head()
# Out:
# 0    2013-November-26
# 1    2015-November-26
# 2       2014-March-23
# 3       2016-March-23
# 4         2014-May-15
# Name: Calculated_Date, dtype: object

# %%
sales['Calculated_Date'] = sales[['Year', 'Month', 'Day']].apply(lambda x: '{}-{}-{}'.format(x[0], x[1], x[2]), axis=1)

sales['Calculated_Date'].head()
# Out:
# 0    2013-November-26
# 1    2015-November-26
# 2       2014-March-23
# 3       2016-March-23
# 4         2014-May-15
# Name: Calculated_Date, dtype: object

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Parse your `Calculated_Date` column into a datetime object

# %%
# your code goes here
sales['Calculated_Date']=pd.to_datetime(sales['Calculated_Date'])
sales['Calculated_Date']
# Out:
# 0        2013-11-26
# 1        2015-11-26
# 2        2014-03-23
# 3        2016-03-23
# 4        2014-05-15
#             ...
# 113031   2016-04-12
# 113032   2014-04-02
# 113033   2016-04-02
# 113034   2014-03-04
# 113035   2016-03-04
# Name: Calculated_Date, Length: 113036, dtype: datetime64[ns]

# %%
sales['Calculated_Date'] = pd.to_datetime(sales['Calculated_Date'])

sales['Calculated_Date'].head()
# Out:
# 0   2013-11-26
# 1   2015-11-26
# 2   2014-03-23
# 3   2016-03-23
# 4   2014-05-15
# Name: Calculated_Date, dtype: datetime64[ns]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How did sales evolve through the years?
#
# Show a <b>line plot</b> using `Calculated_Date` column as the x-axis and the count of sales as the y-axis.

# %%
# your code goes here

sales['Calculated_Date'].value_counts().plot(kind='line',figsize=(14,6))
# sales.groupby('Calculated_Date').nunique().plot(kind='line', figsize=(14,6))
# Out:
# <AxesSubplot:>

# %%
sales.head(23)
# sales.drop('count', axis=1 , inplace=True)
# Out:
#          Date  Day      Month  Year  Customer_Age             Age_Group  \
# 0  2013-11-26   26   November  2013            19           Youth (<25)
# 1  2015-11-26   26   November  2015            19           Youth (<25)
# 2  2014-03-23   23      March  2014            49        Adults (35-64)
# 3  2016-03-23   23      March  2016            49        Adults (35-64)
# 4  2014-05-15   15        May  2014            47        Adults (35-64)
# 5  2016-05-15   15        May  2016            47        Adults (35-64)
# 6  2014-05-22   22        May  2014            47        Adults (35-64)
# 7  2016-05-22   22        May  2016            47        Adults (35-64)
# 8  2014-02-22   22   February  2014            35        Adults (35-64)
# 9  2016-02-22   22   February  2016            35        Adults (35-64)
# 10 2013-07-30   30       July  2013            32  Young Adults (25-34)
# 11 2015-07-30   30       July  2015            32  Young Adults (25-34)
# ...

# %%
print(sales['Calculated_Date'].value_counts())
sales['Calculated_Date'].value_counts().plot(kind='line', figsize=(14,6))
# Out:
# 2014-03-01    288
# 2016-03-01    288
# 2013-12-07    241
# 2015-12-07    241
# 2014-06-14    236
#              ...
# 2011-02-21      1
# 2012-11-04      1
# 2011-05-29      1
# 2012-05-29      1
# 2012-02-21      1
# Name: Calculated_Date, Length: 1884, dtype: int64
# <AxesSubplot:>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Increase 50 U$S revenue to every sale

# %%
# your code goes here
sales['Revenue'] += 50

# %%
#sales['Revenue'] = sales['Revenue'] + 50

sales['Revenue'] += 50

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made in `Canada` or `France`?

# %%
# your code goes here
sales.loc[(sales['Country'] == 'Canada')|(sales['Country'] == 'France')].shape
# Out:
# (25176, 20)

# %%
sales.loc[(sales['Country'] == 'Canada') | (sales['Country'] == 'France')].shape[0]
# Out:
# 25176

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many `Bike Racks` orders were made from Canada?

# %%
# your code goes here
sales.loc[(sales['Country'] == 'Canada')&(sales['Sub_Category'] == 'Bike Racks')].shape[0]
# Out:
# 104

# %%
sales.loc[(sales['Country'] == 'Canada') & (sales['Sub_Category'] == 'Bike Racks')].shape[0]
# Out:
# 104

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made in each region (state) of France?

# %%
# your code goes here
sales['count'] = 1

france = sales.loc[sales['Country'] == 'France'].groupby(['Country','State']).count()['count'].sort_values(ascending=False)
france
# Out:
# Country  State
# France   Seine (Paris)        2328
#          Seine Saint Denis    1684
#          Nord                 1670
#          Hauts de Seine       1084
#          Essonne               994
#          Yveline               954
#          Seine et Marne        394
#          Moselle               386
#          Loiret                382
#          Val d'Oise            264
#          Garonne (Haute)       208
#          Val de Marne          158
#          Charente-Maritime     148
#          Somme                 134
#          Loir et Cher          120
#          Pas de Calais          90
# Name: count, dtype: int64

# %%
france_states = sales.loc[sales['Country'] == 'France', 'State'].value_counts()

france_states
# Out:
# Seine (Paris)        2328
# Seine Saint Denis    1684
# Nord                 1670
# Hauts de Seine       1084
# Essonne               994
# Yveline               954
# Seine et Marne        394
# Moselle               386
# Loiret                382
# Val d'Oise            264
# Garonne (Haute)       208
# Val de Marne          158
# Charente-Maritime     148
# Somme                 134
# Loir et Cher          120
# Pas de Calais          90
# Name: State, dtype: int64

# %% [markdown]
# Go ahead and show a <b>bar plot</b> with the results:

# %%
# your code goes here
france.plot(kind='bar', figsize=(14,6))
# Out:
# <AxesSubplot:xlabel='Country,State'>

# %%
france_states.plot(kind='bar', figsize=(14,6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales were made per category?

# %%
# your code goes here
sales['Product_Category'].value_counts()
# Out:
# Accessories    70120
# Bikes          25982
# Clothing       16934
# Name: Product_Category, dtype: int64

# %%
sales['Product_Category'].value_counts()
# Out:
# Accessories    70120
# Bikes          25982
# Clothing       16934
# Name: Product_Category, dtype: int64

# %% [markdown]
# Go ahead and show a <b>pie plot</b> with the results:

# %%
# your code goes here
plt.figure(figsize=(16,8))
ax1 = plt.subplot(121, aspect='equal')
sales['Product_Category'].value_counts().plot(kind='pie', ax=ax1, autopct='%1.1f%%', 
 startangle=40, shadow=False, legend = True, fontsize=14)
# Out:
# <AxesSubplot:ylabel='Product_Category'>

# %%
sales['Product_Category'].value_counts().plot(kind='pie', figsize=(6,6))
# Out:
# <AxesSubplot:ylabel='Product_Category'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made per accessory sub-categories?

# %%
# your code goes here
accessory = sales.loc[sales['Product_Category']=='Accessories','Sub_Category'].value_counts()
accessory
# Out:
# Tires and Tubes      33870
# Bottles and Cages    15876
# Helmets              12158
# Fenders               4032
# Cleaners              1802
# Hydration Packs       1334
# Bike Racks             592
# Bike Stands            456
# Name: Sub_Category, dtype: int64

# %%
accessories = sales.loc[sales['Product_Category'] == 'Accessories', 'Sub_Category'].value_counts()

accessories
# Out:
# Tires and Tubes      33870
# Bottles and Cages    15876
# Helmets              12158
# Fenders               4032
# Cleaners              1802
# Hydration Packs       1334
# Bike Racks             592
# Bike Stands            456
# Name: Sub_Category, dtype: int64

# %% [markdown]
# Go ahead and show a <b>bar plot</b> with the results:

# %%
# your code goes here
accessory.plot(kind='bar',alpha=0.5,figsize=(14,6))
# Out:
# <AxesSubplot:>

# %%
accessories.plot(kind='bar', figsize=(14,6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made per bike sub-categories?

# %%
# your code goes here
bikes = sales.loc[sales['Product_Category'] == 'Bikes', 'Sub_Category'].value_counts()
bikes
# Out:
# Road Bikes        13430
# Mountain Bikes     8854
# Touring Bikes      3698
# Name: Sub_Category, dtype: int64

# %%
bikes = sales.loc[sales['Product_Category'] == 'Bikes', 'Sub_Category'].value_counts()

bikes
# Out:
# Road Bikes        13430
# Mountain Bikes     8854
# Touring Bikes      3698
# Name: Sub_Category, dtype: int64

# %% [markdown]
# Go ahead and show a <b>pie plot</b> with the results:

# %%
# your code goes here
plt.figure(figsize=(16,8))
ax1 = plt.subplot(121, aspect='equal')
bikes.plot(kind='pie', ax=ax1, autopct='%1.1f%%', 
 startangle=40, shadow=False, legend = True, fontsize=14)
# Out:
# <AxesSubplot:ylabel='Sub_Category'>

# %%
bikes.plot(kind='pie', figsize=(6,6))
# Out:
# <AxesSubplot:ylabel='Sub_Category'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Which gender has the most amount of sales?

# %%
# your code goes here
# sales['Product_Category'].value_counts().head(1)
sales['Customer_Gender'].value_counts()
# Out:
# M    58312
# F    54724
# Name: Customer_Gender, dtype: int64

# %%
sales['Customer_Gender'].value_counts()
# Out:
# M    58312
# F    54724
# Name: Customer_Gender, dtype: int64

# %%
sales['Customer_Gender'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales with more than 500 in `Revenue` were made by men?

# %%
# your code goes here
sales.loc[(sales['Customer_Gender']=='M')&(sales['Revenue']>500)].shape[0]
# Out:
# 24843

# %%
sales.loc[(sales['Customer_Gender'] == 'M') & (sales['Revenue'] == 500)].shape[0]
# Out:
# 9

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Get the top-5 sales with the highest revenue

# %%
# your code goes here
# sales['Revenue'].value_counts().head(5)
sales.sort_values(by=['Revenue'], ascending=False).head(5)
# Out:
#              Date  Day      Month  Year  Customer_Age       Age_Group  \
# 112073 2015-07-24   24       July  2015            52  Adults (35-64)
# 112072 2013-07-24   24       July  2013            52  Adults (35-64)
# 71129  2011-07-08    8       July  2011            22     Youth (<25)
# 70307  2011-04-30   30      April  2011            44  Adults (35-64)
# 70601  2011-09-30   30  September  2011            19     Youth (<25)
#
#        Customer_Gender    Country             State Product_Category  ...  \
# 112073               M  Australia        Queensland         Clothing  ...
# 112072               M  Australia        Queensland         Clothing  ...
# 71129                M     Canada           Alberta            Bikes  ...
# 70307                M     Canada  British Columbia            Bikes  ...
# 70601                F     Canada  British Columbia            Bikes  ...
#
#                         Product Order_Quantity  Unit_Cost  Unit_Price  Profit  \
# ...

# %%
sales.sort_values(['Revenue'], ascending=False).head(5)
# Out:
#              Date  Day      Month  Year  Customer_Age       Age_Group  \
# 112073 2015-07-24   24       July  2015            52  Adults (35-64)
# 112072 2013-07-24   24       July  2013            52  Adults (35-64)
# 71129  2011-07-08    8       July  2011            22     Youth (<25)
# 70307  2011-04-30   30      April  2011            44  Adults (35-64)
# 70601  2011-09-30   30  September  2011            19     Youth (<25)
#
#        Customer_Gender    Country             State Product_Category  ...  \
# 112073               M  Australia        Queensland         Clothing  ...
# 112072               M  Australia        Queensland         Clothing  ...
# 71129                M     Canada           Alberta            Bikes  ...
# 70307                M     Canada  British Columbia            Bikes  ...
# 70601                F     Canada  British Columbia            Bikes  ...
#
#                         Product Order_Quantity  Unit_Cost  Unit_Price  Profit  \
# ...

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Get the sale with the highest revenue

# %%
# your code goes here
# sales.sort_values(by=['Revenue'], ascending=False).head(1)
max_sales = sales['Revenue'].idxmax()
sales.loc[max_sales]
# Out:
# Date                    2015-07-24 00:00:00
# Day                                      24
# Month                                  July
# Year                                   2015
# Customer_Age                             52
# Age_Group                    Adults (35-64)
# Customer_Gender                           M
# Country                           Australia
# State                            Queensland
# Product_Category                   Clothing
# Sub_Category                          Vests
# Product             Touring-1000 Yellow, 50
# Order_Quantity                           29
# Unit_Cost                              1482
# Unit_Price                             2384
# Profit                                15096
# Cost                                  42978
# Revenue                               58174
# Count                                     1
# Calculated_Date         2015-07-24 00:00:00
# count                                     1
# Name: 112073, dtype: object

# %%
#sales.sort_values(['Revenue'], ascending=False).head(1)

cond = sales['Revenue'] == sales['Revenue'].max()

sales.loc[cond]
# Out:
#              Date  Day Month  Year  Customer_Age       Age_Group  \
# 112073 2015-07-24   24  July  2015            52  Adults (35-64)
#
#        Customer_Gender    Country       State Product_Category  ...  \
# 112073               M  Australia  Queensland         Clothing  ...
#
#                         Product Order_Quantity  Unit_Cost  Unit_Price  Profit  \
# 112073  Touring-1000 Yellow, 50             29       1482        2384   15096
#
#          Cost  Revenue  Count  Calculated_Date count
# 112073  42978    58174      1       2015-07-24     1
#
# [1 rows x 21 columns]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What is the mean `Order_Quantity` of orders with more than 10K in revenue?

# %%
# your code goes here
sales['Order_Quantity'].loc[sales['Revenue']>10000].mean()
# Out:
# 3.6853932584269664

# %%
cond = sales['Revenue'] > 10_000

sales.loc[cond, 'Order_Quantity'].mean()
# Out:
# 3.6853932584269664

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What is the mean `Order_Quantity` of orders with less than 10K in revenue?

# %%
# your code goes here
sales['Order_Quantity'].loc[sales['Revenue']<10000].mean()
# Out:
# 11.914618369987064

# %%
cond = sales['Revenue'] < 10_000

sales.loc[cond, 'Order_Quantity'].mean()
# Out:
# 11.914618369987064

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made in May of 2016?

# %%
# your code goes here
sales.loc[(sales['Year']==2016) & (sales['Month']=='May')].shape[0]
# Out:
# 5015

# %%
cond = (sales['Year'] == 2016) & (sales['Month'] == 'May')

sales.loc[cond].shape[0]
# Out:
# 5015

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made between May and July of 2016?

# %%
# your code goes here
sales.loc[(sales['Year']==2016) & (sales['Month'].isin(['May','June', 'July']))].shape[0]
# Out:
# 12164

# %%
cond = (sales['Year'] == 2016) & (sales['Month'].isin(['May', 'June', 'July']))

sales.loc[cond].shape[0]
# Out:
# 12164

# %% [markdown]
# Show a grouped <b>box plot</b> per month with the profit values.

# %%
# your code goes here
# fig, (ax1, ax2) = plt.subplots(2,1)
# ax1 = sales.loc[sales['Year']==2016,['Profit', 'Month']]
# ax2 = sales.loc[sales['Year']==2015,['Profit', 'Month']]
# ax1.boxplot(by='Month')
# ax2.boxplot(by='Month')

# fig, axes = plt.subplots(1, 2, sharex=True, figsize=(10,5))
# fig.suptitle('Bigger 1 row x 2 columns axes with no data')

# axes[0] = sales.loc[sales['Year']==2015,['Profit', 'Month']]
# sns.boxplot(ax=axes[0],by='Month')
# axes[0].set_title('Title of the first chart')

# axes[1] = sales.loc[sales['Year']==2016,['Profit', 'Month']]
# sns.boxplot(ax=axes[1],by='Month')
# axes[1].set_title('Title of the Second chart')


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,7))
fig.suptitle('Bigger 1 row x 2 columns axes with no data')

sales.loc[sales['Year']==2015,['Profit', 'Month']].boxplot(ax=ax1, by="Month")
sales.loc[sales['Year']==2016,['Profit', 'Month']].boxplot(ax=ax2, by="Month")
# Out:
# <AxesSubplot:title={'center':'Profit'}, xlabel='[Month]'>

# %%
profit_2016 = sales.loc[sales['Year'] == 2016, ['Profit', 'Month']]

profit_2016.boxplot(by='Month', figsize=(14,6))
# Out:
# <AxesSubplot:title={'center':'Profit'}, xlabel='[Month]'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add 7.2% TAX on every sale `Unit_Price` within United States

# %%
# your code goes here
sales['Unit_Price'].loc[sales['Country']=='United States'].div(1.072**-1)
# Out:
# 22        147.831030
# 23        147.831030
# 34        147.831030
# 35        147.831030
# 38        147.831030
#              ...
# 113021     78.843216
# 113022     78.843216
# 113023     78.843216
# 113024     78.843216
# 113025     78.843216
# Name: Unit_Price, Length: 39206, dtype: float64

# %%
#sales.loc[sales['Country'] == 'United States', 'Unit_Price'] = sales.loc[sales['Country'] == 'United States', 'Unit_Price'] * 1.072

sales.loc[sales['Country'] == 'United States', 'Unit_Price'] *= 1.072

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
